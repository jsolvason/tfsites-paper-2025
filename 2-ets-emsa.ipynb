# %%
import pandas as pd
import seaborn as sns
import js
import matplotlib.pyplot as plt

# %%
# see "2-affinities/raw-emsa-data.xlsx"
cons=1.0
CGAW=9.66232E-05
GCAW=7.89261E-05
GGAC=0.863181316
ETSA=0.028299442

# %%
data=[cons,GGAC,CGAW,GCAW,ETSA]
fig,ax=js.quickfig()
ax.bar(x=range(len(data)),height=data,color='grey')
ax.set_xticklabels(['','cons','ggac','gcaw','gcaw','etsa'])
fig.savefig('2-affinities/emsa.svg')
# Out:
# /var/folders/w_/c5c_656n15798dlm00g7fp6r0000gn/T/ipykernel_7709/2339484215.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['','cons','ggac','gcaw','gcaw','etsa'])
